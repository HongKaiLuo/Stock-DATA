# %%
! pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ivan\anaconda3\lib\site-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ivan\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ivan\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\ivan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ivan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ivan\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ivan\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ivan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ivan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ivan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ivan\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %% [raw]
# import yfinance as yf

# %%
import pandas as pd

# %%
import yfinance as yf

# %%
ticker='AMZN'

# %%
start_data='1990-01-01'

# %%
end_data='2024-04-22'

# %%
data=yf.download(ticker,period='10y', interval ='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2014-04-28  118.5  120.0  117.5  119.0  88.085938  28017000
# 2014-04-29  120.5  121.0  119.0  120.5  89.196259  21769000
# 2014-04-30  120.0  120.5  117.0  118.5  87.715820  43654000
# 2014-05-02  119.0  119.5  117.0  118.0  87.345711  42629000
# 2014-05-05  117.5  118.0  116.0  117.0  86.605507  28604000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['Adj Close'].plot(figsize=(10,7))
plt.title("Adjusted Close Price of %s"%ticker,fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.grid(which='major',color='k',linestyle='-.',linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import yfinance as yf

# %%
tickers_list=['AMZN','IBM','2330.tw']

# %%
data=pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
    data[ticker]=yf.download(ticker,period='10y',interval='1d')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                AMZN         IBM    2330.tw
# Date
# 2014-04-28  14.8290  120.915726  88.085945
# 2014-04-29  15.0190  122.149055  89.196274
# 2014-04-30  15.2065  123.000504  87.715828
# 2014-05-01  15.3945  121.159866        NaN
# 2014-05-02  15.4005  119.851402  87.345726

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price", fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.grid(which="major",color='k',linestyle='-.',linewidth=0.5)
plt.show()
